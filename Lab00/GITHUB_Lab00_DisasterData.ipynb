# %% [markdown]
# # **Objective:**
# The objective of this session is to refresh our basic Python skills by calculating some simple summary statistics for data in a CSV file, this time using a customized Python class object.

# %% [markdown]
# ### The Scenario
#
# You are working on a research project that is trying to assess the
# impact of wind-related disasters in terms of human deaths and property
# damage.  You have been given a comma separated value (CSV) file from the
# EM-DAT: The OFDA/CRED International Disaster Database
# (Data version: v06.01, Created on: Feb-7-2006), downloaded
# from the website http://www.em-dat.net, and in the form of
# the file ``wind_disasters.csv``.

# %% [markdown]
# ### The Overall Objective
#
# *For a specified range of years*, you need to answer the following simple questions.
# * How many disasters were there in each year?
# * What were the total number of deaths in each year from wind-related disasters?
# * What was the aggregate damage in each year from wind-related disasters?
# * What was the maximum number of deaths from a single disaster in each year?
# * What was the maximum amount of  damage from a single disaster in each year?
#
# Working with your research colleagues, you have decided to
# write a simple Python program that will help you answer these questions.

# %% [markdown]
# ### The Computational Task
#
# As you know, computation is the transformation from input to output.  So let's get our inputs and outputs specified.
#
# #### Inputs:
# * ``input_filename`` = the name of the file to read in (example: ``wind_disasters.csv``)
# * ``start_year`` = the first year to consider in the analysis (example: ``1955``)
# * ``end_year`` = the last year to consider in the analysis (example: ``1960``)
#
# #### Outputs:
# We need to open the specified file, read it line-by-line, and calculate the
# following summary statistics *for each year* in the range of years under consideration:
# * ``num_disasters`` = the total number of disasters that year
# * ``total_deaths`` = the total number of deaths across all disasters that year
# * ``total_damage`` = the total damage across all disasters that year
# * ``max_deaths`` = the largest number of casualties in a single disaster that year
# * ``max_cost`` = the largest amount of damage in a single disaster that year
#
# Our output should have a single line for each year in the specified range (in order!) with the following data:
# ```
# YYYY, num_disasters, total_deaths, total_damage, max_deaths, max_cost
# ```
#
# For example, running with parameters:
# ```
# wind_disasters.csv, 1955, 1960
# ```
#
# should yield output containing the following data:
# ```
# 1955,19,3895,877000,1500,832000
# 1956,14,3114,0,2000,0
# 1957,9,1139,150000,390,150000
# 1958,13,2620,0,1175,0
# 1959,16,9695,672200,5098,600000
# 1960,20,9164,454041,5149,387000
# ```

# %% [markdown]
# Okay, this type of thing sounds pretty familiar.  This task is a good candidate for a function.
#
# Specifically, let's write a function called ``parse_disasters()`` that does the following:
# * open the file, read line-by-line, and parse its text...
# We can add more functionality later

# %%
def calc_disasters(infile,start_year,end_year,isVerbose = True):
    '''function to calculate summary disaster statistics in range [start_year,end_year]
       for data in given filename.'''

    if isVerbose:
        print("Calculating statistics in file %s for range [%d,%d]." % 
              (infile, start_year, end_year))

    # open the file and get a "handle" on it
    file = open(infile, "r")

    # index to identify the first line or first apparence of a year
    i=0

    # looping throught the whole file once
    counter = 3
    for line in file:

        # remove the special characters
        line = line.strip()  # string method that removes whitespace and special chars

        # skip any line with first character # 
        if line[0] == '#':
            continue

        # parse by comma
        values = line.split(',')

        # give all tokens names to work with
        # type          - the type of disaster  -->typ
        # event_name    - the name of the disaster (if it exists)
        # num_killed    - the number of fatalities
        # damage        - total damage (in adjusted USD)
        # start_year    - year in which the disaster began  ---> year
        # start_month   - month in which the disaster began
        # start_day     - day of month on which the disaster began
        # iso           - three-letter country code
        # country_name  - full name
        # region        - global region
        # continent     - continent
        try:
            # Col 1
            typ = values[0].strip()             # strip() removes leading/trailing blanks
            if len(typ)==0:
                typ = 'NA'
            else:
                typ = typ
            
            # Col 2 
            event_name = values[1].strip()
            if len(event_name) == 0:
                event_name = 'NA'
            else:
                event_name = values[1].strip()
            
            # Col 3
            num_killed = int(values[2])
            if num_killed == '':
                num_killed = 'NA'
            else:
                num_killed = num_killed 
                
            # Col 4
            damage = int(values[3])
            if damage == '':
                damage = 'NA'
            else:
                damage = damage
            
            #Col 5
            year = int(values[4])
            if year == '':
                year = 'NA'
            else:
                year = year
            
            #Col 6
            start_month = int(values[5])
            if start_month == '':
                start_month = 'NA'
            else:
                start_month = start_month
                
            # Col 7
            start_day = int(values[6])
            if start_day == '':
                start_day = 'NA'
            else:
                start_day = start_day
                
            # Col 8
            iso = values[7].strip()
            if len(iso) == 0:
                iso = 'NA'
            else:
                iso = iso
                
            # Col 9
            country_name = values[8].strip()
            if len(country_name) == 0:
                country_name = 'NA'
            else:
                country_name = country_name
                
            # Col 10
            region = values[9].strip()
            if len(region) == 0:
                region = 'NA'
            else:
                region = region
                
            # Col 11
            continent = values[10].strip()
            if len(continent) == 0:
                continent = 'NA'
            else:
                continent = continent
        
        except ValueError:
             # Col 1
#             typ = values[0].strip()             # strip() removes leading/trailing blanks
            if len(typ)==0:
                typ = 'NA'
            else:
                typ = typ
            
            # Col 2 
#             event_name = values[1].strip()
            if len(event_name) == 0:
                event_name = 'NA'
            else:
                event_name = values[1].strip()
            
            # Col 3
            num_killed = (values[2])
            print(num_killed)
            if num_killed == '':
                num_killed = 'NA'
            else:
                num_killed = num_killed 
                
            # Col 4
            damage = (values[3])
            if damage == '':
                damage = 'NA'
            else:
                damage = damage
            
            #Col 5
#             year = (values[4])
            if year == '':
                year = 'NA'
            else:
                year = year
            
            #Col 6
            start_month = (values[5])
            if start_month == '':
                start_month = 'NA'
            else:
                start_month = start_month
                
            # Col 7
            start_day = (values[6])
            if start_day == '':
                start_day = 'NA'
            else:
                start_day = start_day
                
            # Col 8
            iso = values[7].strip()
            if len(iso) == 0:
                iso = 'NA'
            else:
                iso = iso
                
            # Col 9
            country_name = values[8].strip()
            if len(country_name) == 0:
                country_name = 'NA'
            else:
                country_name = country_name
                
            # Col 10
            region = values[9].strip()
            if len(region) == 0:
                region = 'NA'
            else:
                region = region
                
            # Col 11
            continent = values[10].strip()
            if len(continent) == 0:
                continent = 'NA'
            else:
                continent = continent
            
        counter += 1
        if isVerbose:
            print('Row:%d, Read... Event Type: %s, Event Name: %s:'% 
                  (counter, typ,event_name), (num_killed,damage,year))

# %%
calc_disasters('wind_disasters.csv',1955,1960)
# Out:
# Calculating statistics in file wind_disasters.csv for range [1955,1960].
# Row:4, Read... Event Type: Storm, Event Name: NA: (10, 0, 1993)
# Row:5, Read... Event Type: Winter, Event Name: NA: (260, 0, 2005)
# Row:6, Read... Event Type: Winter, Event Name: NA: (6, 0, 2002)
# Row:7, Read... Event Type: Winter, Event Name: NA: (2, 0, 2005)
# Row:8, Read... Event Type: Storm, Event Name: NA: (0, 0, 1988)
# Row:9, Read... Event Type: Storm, Event Name: NA: (4, 0, 2000)
# Row:10, Read... Event Type: Winter, Event Name: NA: (13, 0, 2003)
# Row:11, Read... Event Type: Winter, Event Name: NA: (10, 0, 2005)
# Row:12, Read... Event Type: Cyclone, Event Name: NA: (90, 0, 1966)
# Row:13, Read... Event Type: Cyclone, Event Name: Gina: (0, 5000, 1989)
# Row:14, Read... Event Type: Cyclone, Event Name: Heta: (0, 150000, 2004)
# Row:15, Read... Event Type: Cyclone, Event Name: Olaf: (0, 0, 2005)
# Row:16, Read... Event Type: Hurricane, Event Name: Alice: (0, 0, 1955)
# Row:17, Read... Event Type: Hurricane, Event Name: Donna: (5, 35000, 1960)
# Row:18, Read... Event Type: Hurricane, Event Name: Frederic: (0, 0, 1979)
# Row:19, Read... Event Type: Tornado, Event Name: NA: (0, 160, 1983)
# Row:20, Read... Event Type: Hurricane, Event Name: Klaus: (0, 2115, 1984)
# Row:21, Read... Event Type: Hurricane, Event Name: Lenny: (0, 50, 1999)
# Row:22, Read... Event Type: Hurricane, Event Name: Dog: (2, 1000, 1950)
# Row:23, Read... Event Type: Hurricane, Event Name: Donna: (2, 0, 1960)
# Row:24, Read... Event Type: Hurricane, Event Name: Inez: (0, 0, 1966)
# Row:25, Read... Event Type: Hurricane, Event Name: Hugo: (2, 80000, 1989)
# Row:26, Read... Event Type: Hurricane, Event Name: Gustav: (0, 0, 1990)
# Row:27, Read... Event Type: Hurricane, Event Name: Luis: (2, 300000, 1995)
# Row:28, Read... Event Type: Hurricane, Event Name: Georges: (2, 60000, 1998)
# Row:29, Read... Event Type: Hurricane, Event Name: Jose: (1, 0, 1999)
# Row:30, Read... Event Type: Hurricane, Event Name: Lenny: (0, 0, 1999)
# Row:31, Read... Event Type: Tornado, Event Name: NA: (60, 0, 1973)
# Row:32, Read... Event Type: Storm, Event Name: NA: (100, 0, 1974)
# Row:33, Read... Event Type: Storm, Event Name: NA: (20, 0, 1975)
# Row:34, Read... Event Type: Storm, Event Name: NA: (5, 0, 1978)
# Row:35, Read... Event Type: Tornado, Event Name: NA: (1, 0, 1986)
# Row:36, Read... Event Type: Storm, Event Name: NA: (1, 10000, 1987)
# Row:37, Read... Event Type: Storm, Event Name: NA: (15, 50000, 1993)
# Row:38, Read... Event Type: Storm, Event Name: NA: (6, 0, 1995)
# Row:39, Read... Event Type: Storm, Event Name: NA: (0, 0, 1998)
# Row:40, Read... Event Type: Winter, Event Name: NA: (0, 0, 2000)
# Row:41, Read... Event Type: Storm, Event Name: NA: (1, 0, 2000)
# Row:42, Read... Event Type: Storm, Event Name: NA: (4, 0, 2001)
# Row:43, Read... Event Type: Storm, Event Name: NA: (16, 15000, 2001)
# Row:44, Read... Event Type: Storm, Event Name: NA: (3, 0, 2002)
# Row:45, Read... Event Type: Storm, Event Name: NA: (12, 0, 2003)
# Row:46, Read... Event Type: Storm, Event Name: NA: (11, 0, 2005)
# Row:47, Read... Event Type: Cyclone, Event Name: Ada: (13, 72475, 1970)
# Row:48, Read... Event Type: Cyclone, Event Name: Althea: (3, 119219, 1971)
# Row:49, Read... Event Type: Cyclone, Event Name: Tracy: (65, 800000, 1974)
# Row:50, Read... Event Type: Cyclone, Event Name: Wanda: (11, 296717, 1974)
# Row:51, Read... Event Type: Cyclone, Event Name: Joan: (0, 63861, 1975)
# Row:52, Read... Event Type: Storm, Event Name: NA: (0, 13037, 1976)
# Row:53, Read... Event Type: Tornado, Event Name: NA: (0, 7279, 1976)
# Row:54, Read... Event Type: Storm, Event Name: NA: (0, 38024, 1976)
# Row:55, Read... Event Type: Cyclone, Event Name: David: (0, 4237, 1976)
# Row:56, Read... Event Type: Cyclone, Event Name: Beth: (0, 8257, 1976)
# Row:57, Read... Event Type: Cyclone, Event Name: Ted: (0, 36177, 1976)
# Row:58, Read... Event Type: Storm, Event Name: NA: (0, 38680, 1977)
# Row:59, Read... Event Type: Storm, Event Name: NA: (0, 10269, 1977)
# Row:60, Read... Event Type: Cyclone, Event Name: Alby: (5, 1000000, 1978)
# Row:61, Read... Event Type: Storm, Event Name: NA: (0, 3797, 1978)
# Row:62, Read... Event Type: Storm, Event Name: NA: (0, 35090, 1978)
# Row:63, Read... Event Type: Storm, Event Name: NA: (0, 11620, 1978)
# Row:64, Read... Event Type: Storm, Event Name: NA: (0, 16107, 1978)
# Row:65, Read... Event Type: Cyclone, Event Name: Hazel: (15, 31286, 1979)
# Row:66, Read... Event Type: Storm, Event Name: NA: (0, 18683, 1979)
# Row:67, Read... Event Type: Cyclone, Event Name: Amy: (0, 6966, 1980)
# Row:68, Read... Event Type: Cyclone, Event Name: Dean: (0, 40026, 1980)
# Row:69, Read... Event Type: Cyclone, Event Name: Enid: (0, 4605, 1980)
# Row:70, Read... Event Type: Cyclone, Event Name: NA: (0, 13932, 1980)
# Row:71, Read... Event Type: Storm, Event Name: NA: (0, 29399, 1980)
# Row:72, Read... Event Type: Storm, Event Name: NA: (0, 7895, 1981)
# Row:73, Read... Event Type: Cyclone, Event Name: Dominic: (1, 6864, 1982)
# Row:74, Read... Event Type: Storm, Event Name: NA: (0, 12454, 1982)
# Row:75, Read... Event Type: Storm, Event Name: NA: (0, 11767, 1982)
# Row:76, Read... Event Type: Storm, Event Name: NA: (0, 1984, 1983)
# Row:77, Read... Event Type: Storm, Event Name: NA: (0, 2255, 1983)
# Row:78, Read... Event Type: Storm, Event Name: NA: (0, 5773, 1983)
# Row:79, Read... Event Type: Storm, Event Name: NA: (27, 122000, 1985)
# Row:80, Read... Event Type: Storm, Event Name: NA: (0, 7255, 1985)
# Row:81, Read... Event Type: Cyclone, Event Name: Winifred: (3, 70000, 1986)
# Row:82, Read... Event Type: Storm, Event Name: NA: (0, 51000, 1986)
# Row:83, Read... Event Type: Storm, Event Name: NA: (0, 5778, 1986)
# Row:84, Read... Event Type: Storm, Event Name: NA: (4, 68055, 1986)
# Row:85, Read... Event Type: Storm, Event Name: NA: (0, 6806, 1986)
# Row:86, Read... Event Type: Cyclone, Event Name: Charlie: (1, 20417, 1988)
# Row:87, Read... Event Type: Cyclone, Event Name: Aivu: (2, 94300, 1989)
# Row:88, Read... Event Type: Cyclone, Event Name: Orson: (2, 13611, 1989)
# Row:89, Read... Event Type: Storm, Event Name: NA: (0, 275000, 1990)
# Row:90, Read... Event Type: Cyclone, Event Name: Joy: (0, 155600, 1990)
# Row:91, Read... Event Type: Storm, Event Name: NA: (0, 0, 1991)
# Row:92, Read... Event Type: Storm, Event Name: NA: (0, 1560, 1991)
# Row:93, Read... Event Type: Storm, Event Name: NA: (0, 103100, 1992)
# Row:94, Read... Event Type: Storm, Event Name: NA: (2, 274900, 1992)
# Row:95, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1993)
# Row:96, Read... Event Type: Storm, Event Name: NA: (0, 0, 1993)
# Row:97, Read... Event Type: Storm, Event Name: NA: (2, 77600, 1994)
# Row:98, Read... Event Type: Storm, Event Name: Hurricane: (22, 0, 1994)
# Row:99, Read... Event Type: Storm, Event Name: NA: (1, 0, 1994)
# Row:100, Read... Event Type: Storm, Event Name: NA: (2, 0, 1994)
# Row:101, Read... Event Type: Cyclone, Event Name: Bobby: (7, 98000, 1995)
# Row:102, Read... Event Type: Tornado, Event Name: NA: (0, 18700, 1995)
# Row:103, Read... Event Type: Storm, Event Name: NA: (1, 84000, 1995)
# Row:104, Read... Event Type: Storm, Event Name: NA: (0, 28000, 1995)
# Row:105, Read... Event Type: Storm, Event Name: NA: (6, 47000, 1996)
# Row:106, Read... Event Type: Storm, Event Name: NA: (0, 9333, 1996)
# Row:107, Read... Event Type: Storm, Event Name: NA: (0, 39200, 1996)
# Row:108, Read... Event Type: Cyclone, Event Name: Olivia: (0, 46700, 1996)
# Row:109, Read... Event Type: Storm, Event Name: NA: (0, 317300, 1996)
# Row:110, Read... Event Type: Storm, Event Name: NA: (1, 140000, 1996)
# Row:111, Read... Event Type: Cyclone, Event Name: Rona: (5, 12547, 1999)
# Row:112, Read... Event Type: Cyclone, Event Name: Vance: (1, 200000, 1999)
# Row:113, Read... Event Type: Storm, Event Name: NA: (1, 640000, 1999)
# Row:114, Read... Event Type: Cyclone, Event Name: Steve: (1, 90000, 2000)
# Row:115, Read... Event Type: Cyclone, Event Name: Tessi: (0, 60000, 2000)
# Row:116, Read... Event Type: Cyclone, Event Name: Sam: (0, 0, 2000)
# Row:117, Read... Event Type: Storm, Event Name: NA: (1, 6600, 2001)
# Row:118, Read... Event Type: Storm, Event Name: NA: (1, 0, 2001)
# Row:119, Read... Event Type: Storm, Event Name: NA: (0, 0, 2001)
# Row:120, Read... Event Type: Storm, Event Name: NA: (0, 0, 2002)
# Row:121, Read... Event Type: Storm, Event Name: NA: (0, 0, 2002)
# Row:122, Read... Event Type: Storm, Event Name: NA: (0, 0, 2002)
# Row:123, Read... Event Type: Storm, Event Name: NA: (1, 0, 2003)
# Row:124, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2003)
# Row:125, Read... Event Type: Storm, Event Name: Hailstorm: (0, 0, 2003)
# Row:126, Read... Event Type: Storm, Event Name: NA: (0, 93000, 2003)
# Row:127, Read... Event Type: Storm, Event Name: NA: (0, 0, 2003)
# Row:128, Read... Event Type: Winter, Event Name: NA: (0, 0, 2004)
# Row:129, Read... Event Type: Storm, Event Name: NA: (2, 10000, 2004)
# Row:130, Read... Event Type: Storm, Event Name: NA: (1, 50000, 2004)
# Row:131, Read... Event Type: Storm, Event Name: NA: (0, 27000, 2005)
# Row:132, Read... Event Type: Storm, Event Name: NA: (3, 7000, 2005)
# Row:133, Read... Event Type: Storm, Event Name: NA: (1, 15000, 2005)
# Row:134, Read... Event Type: Winter, Event Name: NA: (0, 0, 1976)
# Row:135, Read... Event Type: Winter, Event Name: NA: (0, 0, 1981)
# Row:136, Read... Event Type: Storm, Event Name: NA: (12, 200000, 1984)
# Row:137, Read... Event Type: Storm, Event Name: NA: (0, 0, 1990)
# Row:138, Read... Event Type: Storm, Event Name: NA: (0, 37700, 1990)
# Row:139, Read... Event Type: Winter, Event Name: Daria: (3, 238700, 1990)
# Row:140, Read... Event Type: Storm, Event Name: NA: (0, 28000, 1991)
# Row:141, Read... Event Type: Storm, Event Name: NA: (0, 35210, 2000)
# Row:142, Read... Event Type: Storm, Event Name: NA: (2, 0, 2002)
# Row:143, Read... Event Type: Storm, Event Name: NA: (1, 0, 2002)
# Row:144, Read... Event Type: Hurricane, Event Name: NA: (27, 0, 1946)
# Row:145, Read... Event Type: Storm, Event Name: NA: (0, 66000, 1996)
# Row:146, Read... Event Type: Hurricane, Event Name: NA: (0, 0, 1926)
# Row:147, Read... Event Type: Hurricane, Event Name: NA: (0, 0, 1929)
# Row:148, Read... Event Type: Hurricane, Event Name: NA: (14, 0, 1935)
# Row:149, Read... Event Type: Hurricane, Event Name: NA: (22, 0, 1945)
# Row:150, Read... Event Type: Hurricane, Event Name: Flora: (0, 1500, 1963)
# Row:151, Read... Event Type: Hurricane, Event Name: Betsy: (0, 700, 1965)
# Row:152, Read... Event Type: Hurricane, Event Name: Inez: (5, 15500, 1966)
# Row:153, Read... Event Type: Hurricane, Event Name: Inez: (0, 0, 1966)
# Row:154, Read... Event Type: Tropical storm, Event Name: Arthur: (0, 0, 1990)
# Row:155, Read... Event Type: Hurricane, Event Name: Andrew: (4, 250000, 1992)
# Row:156, Read... Event Type: Hurricane, Event Name: Floyd: (1, 0, 1999)
# Row:157, Read... Event Type: Hurricane, Event Name: Michelle: (0, 250000, 2001)
# Row:158, Read... Event Type: Hurricane, Event Name: Frances: (2, 0, 2004)
# Row:159, Read... Event Type: Hurricane, Event Name: Jeanne: (0, 0, 2004)
# Row:160, Read... Event Type: Hurricane, Event Name: Wilma: (0, 0, 2005)
# Row:161, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1904)
# Row:162, Read... Event Type: Cyclone, Event Name: NA: (172, 0, 1909)
# Row:163, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1909)
# Row:164, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1911)
# Row:165, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1919)
# Row:166, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1922)
# Row:167, Read... Event Type: Cyclone, Event Name: NA: (6, 0, 1923)
# Row:168, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1926)
# Row:169, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1937)
# Row:170, Read... Event Type: Cyclone, Event Name: NA: (5000, 0, 1941)
# Row:171, Read... Event Type: Cyclone, Event Name: NA: (61000, 0, 1942)
# Row:172, Read... Event Type: Cyclone, Event Name: NA: (500, 0, 1947)
# Row:173, Read... Event Type: Storm, Event Name: NA: (200, 0, 1951)
# Row:174, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1958)
# Row:175, Read... Event Type: Cyclone, Event Name: NA: (500, 0, 1958)
# Row:176, Read... Event Type: Cyclone, Event Name: NA: (3000, 0, 1960)
# Row:177, Read... Event Type: Cyclone, Event Name: NA: (5149, 0, 1960)
# Row:178, Read... Event Type: Cyclone, Event Name: NA: (11000, 11900, 1961)
# Row:179, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1961)
# Row:180, Read... Event Type: Storm, Event Name: NA: (266, 0, 1961)
# Row:181, Read... Event Type: Cyclone, Event Name: NA: (11500, 46500, 1963)
# Row:182, Read... Event Type: Cyclone, Event Name: NA: (79, 0, 1963)
# Row:183, Read... Event Type: Cyclone, Event Name: NA: (300, 250, 1964)
# Row:184, Read... Event Type: Cyclone, Event Name: NA: (36000, 57700, 1965)
# Row:185, Read... Event Type: Cyclone, Event Name: NA: (12047, 0, 1965)
# Row:186, Read... Event Type: Cyclone, Event Name: NA: (874, 0, 1965)
# Row:187, Read... Event Type: Cyclone, Event Name: NA: (850, 22400, 1966)
# Row:188, Read... Event Type: Cyclone, Event Name: NA: (50, 0, 1967)
# Row:189, Read... Event Type: Cyclone, Event Name: NA: (41, 0, 1967)
# Row:190, Read... Event Type: Cyclone, Event Name: NA: (118, 1500, 1968)
# Row:191, Read... Event Type: Cyclone, Event Name: NA: (849, 8329, 1969)
# Row:192, Read... Event Type: Storm, Event Name: NA: (17, 0, 1970)
# Row:193, Read... Event Type: Storm, Event Name: NA: (300, 0, 1970)
# Row:194, Read... Event Type: Cyclone, Event Name: NA: (300000, 86400, 1970)
# Row:195, Read... Event Type: Cyclone, Event Name: NA: (163, 0, 1971)
# Row:196, Read... Event Type: Tornado, Event Name: NA: (200, 0, 1972)
# Row:197, Read... Event Type: Storm, Event Name: NA: (200, 0, 1973)
# Row:198, Read... Event Type: Cyclone, Event Name: NA: (1000, 0, 1973)
# Row:199, Read... Event Type: Storm, Event Name: NA: (700, 0, 1973)
# Row:200, Read... Event Type: Cyclone, Event Name: NA: (2500, 0, 1974)
# Row:201, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1974)
# Row:202, Read... Event Type: Storm, Event Name: NA: (300, 0, 1974)
# Row:203, Read... Event Type: Tornado, Event Name: NA: (46, 0, 1976)
# Row:204, Read... Event Type: Tornado, Event Name: NA: (1, 201, 1976)
# Row:205, Read... Event Type: Storm, Event Name: NA: (600, 50000, 1977)
# Row:206, Read... Event Type: Cyclone, Event Name: NA: (13, 0, 1977)
# Row:207, Read... Event Type: Tornado, Event Name: NA: (21, 0, 1977)
# Row:208, Read... Event Type: Storm, Event Name: NA: (1000, 0, 1978)
# Row:209, Read... Event Type: Storm, Event Name: NA: (30, 0, 1978)
# Row:210, Read... Event Type: Cyclone, Event Name: NA: (3, 0, 1979)
# Row:211, Read... Event Type: Cyclone, Event Name: NA: (50, 0, 1979)
# Row:212, Read... Event Type: Cyclone, Event Name: NA: (11, 0, 1980)
# Row:213, Read... Event Type: Tornado, Event Name: NA: (70, 0, 1981)
# Row:214, Read... Event Type: Cyclone, Event Name: NA: (1000, 0, 1981)
# Row:215, Read... Event Type: Cyclone, Event Name: NA: (15, 0, 1981)
# Row:216, Read... Event Type: Cyclone, Event Name: NA: (6, 0, 1983)
# Row:217, Read... Event Type: Tornado, Event Name: NA: (12, 0, 1983)
# Row:218, Read... Event Type: Cyclone, Event Name: NA: (600, 0, 1983)
# Row:219, Read... Event Type: Cyclone, Event Name: NA: (67, 0, 1983)
# Row:220, Read... Event Type: Storm, Event Name: NA: (50, 0, 1985)
# Row:221, Read... Event Type: Cyclone, Event Name: NA: (10000, 0, 1985)
# Row:222, Read... Event Type: Storm, Event Name: NA: (71, 0, 1985)
# Row:223, Read... Event Type: Storm, Event Name: NA: (100, 0, 1986)
# Row:224, Read... Event Type: Tropical storm, Event Name: NA: (40, 0, 1986)
# Row:225, Read... Event Type: Cyclone, Event Name: NA: (25, 0, 1986)
# Row:226, Read... Event Type: Storm, Event Name: NA: (19, 0, 1986)
# Row:227, Read... Event Type: Cyclone, Event Name: NA: (12, 0, 1987)
# Row:228, Read... Event Type: Storm, Event Name: NA: (28, 0, 1988)
# Row:229, Read... Event Type: Storm, Event Name: NA: (5, 0, 1988)
# Row:230, Read... Event Type: Cyclone, Event Name: NA: (31, 0, 1988)
# Row:231, Read... Event Type: Cyclone, Event Name: NA: (1000, 0, 1988)
# Row:232, Read... Event Type: Tornado, Event Name: NA: (800, 16200, 1989)
# Row:233, Read... Event Type: Cyclone, Event Name: NA: (15, 0, 1989)
# Row:234, Read... Event Type: Tornado, Event Name: NA: (19, 0, 1990)
# Row:235, Read... Event Type: Tornado, Event Name: NA: (54, 0, 1990)
# Row:236, Read... Event Type: Storm, Event Name: NA: (250, 0, 1990)
# Row:237, Read... Event Type: Cyclone, Event Name: Ofa: (370, 0, 1990)
# Row:238, Read... Event Type: Cyclone, Event Name: Gorky: (138866, 1780000, 1991)
# Row:239, Read... Event Type: Tornado, Event Name: NA: (121, 0, 1991)
# Row:240, Read... Event Type: Storm, Event Name: NA: (7, 0, 1992)
# Row:241, Read... Event Type: Storm, Event Name: NA: (16, 0, 1992)
# Row:242, Read... Event Type: Storm, Event Name: NA: (31, 0, 1993)
# Row:243, Read... Event Type: Cyclone, Event Name: NA: (14, 0, 1993)
# Row:244, Read... Event Type: Storm, Event Name: NA: (8, 0, 1993)
# Row:245, Read... Event Type: Storm, Event Name: NA: (300, 0, 1993)
# Row:246, Read... Event Type: Storm, Event Name: NA: (9, 0, 1993)
# Row:247, Read... Event Type: Storm, Event Name: NA: (25, 0, 1993)
# Row:248, Read... Event Type: Cyclone, Event Name: NA: (50, 0, 1993)
# Row:249, Read... Event Type: Storm, Event Name: NA: (15, 0, 1993)
# Row:250, Read... Event Type: Cyclone, Event Name: NA: (130, 125000, 1994)
# Row:251, Read... Event Type: Cyclone, Event Name: NA: (40, 2500, 1994)
# Row:252, Read... Event Type: Storm, Event Name: NA: (20, 0, 1994)
# Row:253, Read... Event Type: Storm, Event Name: NA: (15, 0, 1994)
# Row:254, Read... Event Type: Storm, Event Name: NA: (69, 0, 1995)
# Row:255, Read... Event Type: Tornado, Event Name: NA: (6, 0, 1995)
# Row:256, Read... Event Type: Storm, Event Name: NA: (525, 800000, 1995)
# Row:257, Read... Event Type: Cyclone, Event Name: NA: (172, 0, 1995)
# Row:258, Read... Event Type: Storm, Event Name: NA: (525, 0, 1996)
# Row:259, Read... Event Type: Storm, Event Name: NA: (60, 0, 1996)
# Row:260, Read... Event Type: Storm, Event Name: NA: (17, 0, 1996)
# Row:261, Read... Event Type: Cyclone, Event Name: NA: (24, 0, 1996)
# Row:262, Read... Event Type: Cyclone, Event Name: One Bravo (01B): (111, 0, 1997)
# Row:263, Read... Event Type: Cyclone, Event Name: Two B: (188, 0, 1997)
# Row:264, Read... Event Type: Tornado, Event Name: NA: (15, 0, 1997)
# Row:265, Read... Event Type: Storm, Event Name: NA: (11, 0, 1997)
# Row:266, Read... Event Type: Storm, Event Name: NA: (100, 0, 1997)
# Row:267, Read... Event Type: Storm, Event Name: NA: (14, 0, 1998)
# Row:268, Read... Event Type: Cyclone, Event Name: 01B: (19, 0, 1998)
# Row:269, Read... Event Type: Cyclone, Event Name: 07B: (200, 0, 1998)
# Row:270, Read... Event Type: Storm, Event Name: NA: (28, 0, 1998)
# Row:271, Read... Event Type: Storm, Event Name: NA: (60, 0, 1998)
# Row:272, Read... Event Type: Storm, Event Name: NA: (7, 0, 1999)
# Row:273, Read... Event Type: Tornado, Event Name: NA: (2, 0, 1999)
# Row:274, Read... Event Type: Storm, Event Name: NA: (3, 0, 1999)
# Row:275, Read... Event Type: Cyclone, Event Name: 05B: (0, 0, 1999)
# Row:276, Read... Event Type: Storm, Event Name: NA: (66, 0, 1999)
# Row:277, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2000)
# Row:278, Read... Event Type: Tropical storm, Event Name: NA: (20, 0, 2000)
# Row:279, Read... Event Type: Storm, Event Name: NA: (0, 0, 2000)
# Row:280, Read... Event Type: Storm, Event Name: NA: (36, 0, 2000)
# Row:281, Read... Event Type: Storm, Event Name: NA: (28, 0, 2000)
# Row:282, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2000)
# Row:283, Read... Event Type: Cyclone, Event Name: NA: (15, 0, 2000)
# Row:284, Read... Event Type: Storm, Event Name: NA: (12, 0, 2001)
# Row:285, Read... Event Type: Storm, Event Name: NA: (193, 0, 2001)
# Row:286, Read... Event Type: Storm, Event Name: NA: (21, 0, 2001)
# Row:287, Read... Event Type: Tornado, Event Name: NA: (12, 0, 2001)
# Row:288, Read... Event Type: Storm, Event Name: NA: (32, 0, 2002)
# Row:289, Read... Event Type: Tropical storm, Event Name: NA: (31, 0, 2002)
# Row:290, Read... Event Type: Storm, Event Name: NA: (10, 0, 2002)
# Row:291, Read... Event Type: Cyclone, Event Name: NA: (49, 0, 2002)
# Row:292, Read... Event Type: Storm, Event Name: NA: (9, 0, 2003)
# Row:293, Read... Event Type: Tropical storm, Event Name: NA: (23, 0, 2003)
# Row:294, Read... Event Type: Tropical storm, Event Name: NA: (28, 0, 2003)
# Row:295, Read... Event Type: Tornado, Event Name: NA: (76, 0, 2004)
# Row:296, Read... Event Type: Storm, Event Name: NA: (153, 0, 2004)
# Row:297, Read... Event Type: Tornado, Event Name: NA: (10, 0, 2004)
# Row:298, Read... Event Type: Storm, Event Name: NA: (0, 0, 2004)
# Row:299, Read... Event Type: Tornado, Event Name: NA: (79, 0, 2005)
# Row:300, Read... Event Type: Tropical storm, Event Name: NA: (11, 0, 2005)
# Row:301, Read... Event Type: Storm, Event Name: NA: (10, 0, 2005)
# Row:302, Read... Event Type: Storm, Event Name: NA: (2, 0, 2005)
# Row:303, Read... Event Type: Storm, Event Name: NA: (11, 0, 2005)
# Row:304, Read... Event Type: Storm, Event Name: NA: (35, 0, 2005)
# Row:305, Read... Event Type: Storm, Event Name: NA: (16, 0, 2005)
# Row:306, Read... Event Type: Hurricane, Event Name: Janet: (57, 0, 1955)
# Row:307, Read... Event Type: Hurricane, Event Name: Allen: (0, 1500, 1980)
# Row:308, Read... Event Type: Hurricane, Event Name: Emily: (0, 100000, 1987)
# Row:309, Read... Event Type: Hurricane, Event Name: Marylin: (0, 0, 1995)
# Row:310, Read... Event Type: Hurricane, Event Name: Lili: (0, 0, 2002)
# Row:311, Read... Event Type: Hurricane, Event Name: Ivan: (1, 0, 2004)
# Row:312, Read... Event Type: Hurricane, Event Name: NA: (5, 150000, 1997)
# Row:313, Read... Event Type: Storm, Event Name: NA: (60, 0, 1930)
# Row:314, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1966)
# Row:315, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1967)
# Row:316, Read... Event Type: Storm, Event Name: NA: (0, 0, 1972)
# Row:317, Read... Event Type: Winter, Event Name: NA: (0, 0, 1976)
# Row:318, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1982)
# Row:319, Read... Event Type: Storm, Event Name: NA: (0, 0, 1984)
# Row:320, Read... Event Type: Storm, Event Name: NA: (0, 0, 1985)
# Row:321, Read... Event Type: Winter, Event Name: Daria: (15, 1038345, 1990)
# Row:322, Read... Event Type: Tornado, Event Name: NA: (0, 486, 1999)
# Row:323, Read... Event Type: Storm, Event Name: NA: (1, 0, 2002)
# Row:324, Read... Event Type: Hurricane, Event Name: NA: (1500, 7500, 1931)
# Row:325, Read... Event Type: Hurricane, Event Name: Janet: (16, 5000, 1955)
# Row:326, Read... Event Type: Hurricane, Event Name: Hattie: (275, 60000, 1961)
# Row:327, Read... Event Type: Hurricane, Event Name: Carmen & Fifi: (0, 4000, 1974)
# Row:328, Read... Event Type: Hurricane, Event Name: Greta: (5, 6000, 1978)
# Row:329, Read... Event Type: Hurricane, Event Name: Mitch: (0, 0, 1998)
# Row:330, Read... Event Type: Hurricane, Event Name: Keith: (14, 277460, 2000)
# Row:331, Read... Event Type: Hurricane, Event Name: Iris: (30, 50080, 2001)
# Row:332, Read... Event Type: Tropical storm, Event Name: Chantal: (0, 0, 2001)
# Row:333, Read... Event Type: Hurricane, Event Name: Wilma: (0, 0, 2005)
# Row:334, Read... Event Type: Storm, Event Name: NA: (0, 0, 2000)
# Row:335, Read... Event Type: Hurricane, Event Name: NA: (0, 0, 1948)
# Row:336, Read... Event Type: Storm, Event Name: NA: (0, 2000, 1985)
# Row:337, Read... Event Type: Tornado, Event Name: NA: (0, 1500, 1986)
# Row:338, Read... Event Type: Hurricane, Event Name: Emily: (0, 50000, 1987)
# Row:339, Read... Event Type: Hurricane, Event Name: Dean: (0, 0, 1989)
# Row:340, Read... Event Type: Hurricane, Event Name: Fabian: (4, 300000, 2003)
# Row:341, Read... Event Type: Cyclone, Event Name: NA: (17, 0, 1994)
# Row:342, Read... Event Type: Winter, Event Name: NA: (20, 0, 2002)
# Row:343, Read... Event Type: Storm, Event Name: NA: (0, 0, 1999)
# Row:344, Read... Event Type: Winter, Event Name: NA: (4, 0, 2005)
# Row:345, Read... Event Type: Storm, Event Name: NA: (100, 0, 1949)
# Row:346, Read... Event Type: Storm, Event Name: NA: (59, 0, 1959)
# Row:347, Read... Event Type: Winter, Event Name: NA: (36, 0, 1966)
# Row:348, Read... Event Type: Storm, Event Name: NA: (10, 0, 1977)
# Row:349, Read... Event Type: Tornado, Event Name: NA: (15, 0, 1980)
# Row:350, Read... Event Type: Storm, Event Name: NA: (33, 0, 1982)
# Row:351, Read... Event Type: Tornado, Event Name: NA: (10, 0, 1984)
# Row:352, Read... Event Type: Storm, Event Name: NA: (22, 0, 1985)
# Row:353, Read... Event Type: Storm, Event Name: NA: (36, 0, 1989)
# Row:354, Read... Event Type: Tornado, Event Name: NA: (0, 21000, 1994)
# Row:355, Read... Event Type: Tornado, Event Name: NA: (0, 70000, 1994)
# Row:356, Read... Event Type: Storm, Event Name: NA: (3, 0, 1997)
# Row:357, Read... Event Type: Storm, Event Name: NA: (13, 0, 2001)
# Row:358, Read... Event Type: Hurricane, Event Name: Catarina: (4, 350000, 2004)
# Row:359, Read... Event Type: Tornado, Event Name: NA: (2, 0, 2005)
# Row:360, Read... Event Type: Winter, Event Name: NA: (0, 0, 1981)
# Row:361, Read... Event Type: Winter, Event Name: NA: (0, 0, 1993)
# Row:362, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1999)
# Row:363, Read... Event Type: Winter, Event Name: NA: (2, 0, 2001)
# Row:364, Read... Event Type: Winter, Event Name: NA: (0, 0, 2005)
# Row:365, Read... Event Type: Storm, Event Name: NA: (0, 0, 1999)
# Row:366, Read... Event Type: Storm, Event Name: NA: (0, 0, 2004)
# Row:367, Read... Event Type: Storm, Event Name: NA: (0, 0, 2004)
# Row:368, Read... Event Type: Tornado, Event Name: NA: (28, 5000, 1912)
# Row:369, Read... Event Type: Storm, Event Name: NA: (17, 500, 1946)
# Row:370, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1950)
# Row:371, Read... Event Type: Hurricane, Event Name: Hazel: (83, 100000, 1954)
# Row:372, Read... Event Type: Winter, Event Name: NA: (6, 0, 1959)
# Row:373, Read... Event Type: Storm, Event Name: NA: (33, 0, 1962)
# Row:374, Read... Event Type: Winter, Event Name: NA: (0, 0, 1966)
# Row:375, Read... Event Type: Storm, Event Name: NA: (10, 0, 1970)
# Row:376, Read... Event Type: Winter, Event Name: NA: (0, 0, 1971)
# Row:377, Read... Event Type: Storm, Event Name: NA: (14, 0, 1975)
# Row:378, Read... Event Type: Storm, Event Name: NA: (0, 2500, 1975)
# Row:379, Read... Event Type: Winter, Event Name: NA: (0, 0, 1977)
# Row:380, Read... Event Type: Storm, Event Name: NA: (0, 79000, 1981)
# Row:381, Read... Event Type: Storm, Event Name: NA: (12, 117000, 1985)
# Row:382, Read... Event Type: Storm, Event Name: NA: (0, 0, 1986)
# Row:383, Read... Event Type: Tornado, Event Name: NA: (26, 330000, 1987)
# Row:384, Read... Event Type: Hurricane, Event Name: Hugo: (0, 0, 1989)
# Row:385, Read... Event Type: Storm, Event Name: NA: (0, 500000, 1991)
# Row:386, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1994)
# Row:387, Read... Event Type: Storm, Event Name: NA: (0, 3000, 1994)
# Row:388, Read... Event Type: Hurricane, Event Name: Luis: (1, 2000, 1995)
# Row:389, Read... Event Type: Winter, Event Name: NA: (28, 1500000, 1998)
# Row:390, Read... Event Type: Winter, Event Name: NA: (0, 0, 1999)
# Row:391, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1999)
# Row:392, Read... Event Type: Tornado, Event Name: NA: (11, 13000, 2000)
# Row:393, Read... Event Type: Storm, Event Name: NA: (11, 0, 2001)
# Row:394, Read... Event Type: Hurricane, Event Name: Isabel: (0, 0, 2003)
# Row:395, Read... Event Type: Hurricane, Event Name: Juan: (2, 110000, 2003)
# Row:396, Read... Event Type: Winter, Event Name: NA: (0, 0, 2004)
# Row:397, Read... Event Type: Winter, Event Name: NA: (0, 0, 2004)
# Row:398, Read... Event Type: Storm, Event Name: NA: (0, 0, 2005)
# Row:399, Read... Event Type: Storm, Event Name: NA: (26, 0, 1957)
# Row:400, Read... Event Type: Storm, Event Name: NA: (0, 415000, 1999)
# Row:401, Read... Event Type: Tropical storm, Event Name: NA: (19, 0, 2005)
# Row:402, Read... Event Type: Cyclone, Event Name: Beryl: (3, 3000, 1982)
# Row:403, Read... Event Type: Tropical storm, Event Name: Fran: (29, 0, 1984)
# Row:404, Read... Event Type: Hurricane, Event Name: Lili: (0, 0, 2002)
# Row:405, Read... Event Type: Hurricane, Event Name: Charley: (0, 0, 2004)
# Row:406, Read... Event Type: Hurricane, Event Name: Ivan: (1, 3430080, 2004)
# Row:407, Read... Event Type: Storm, Event Name: NA: (0, 125, 1981)
# Row:408, Read... Event Type: Storm, Event Name: NA: (3, 0, 2001)
# Row:409, Read... Event Type: Storm, Event Name: NA: (13, 0, 1977)
# Row:410, Read... Event Type: Storm, Event Name: NA: (11, 157, 1988)
# Row:411, Read... Event Type: Storm, Event Name: NA: (58, 0, 1965)
# Row:412, Read... Event Type: Storm, Event Name: NA: (0, 0, 1968)
# Row:413, Read... Event Type: Winter, Event Name: NA: (0, 2500, 1971)
# Row:414, Read... Event Type: Storm, Event Name: NA: (15, 6800, 1977)
# Row:415, Read... Event Type: Winter, Event Name: NA: (85, 0, 1984)
# Row:416, Read... Event Type: Storm, Event Name: NA: (42, 0, 1984)
# Row:417, Read... Event Type: Storm, Event Name: NA: (16, 0, 1986)
# Row:418, Read... Event Type: Winter, Event Name: NA: (0, 0, 1992)
# Row:419, Read... Event Type: Storm, Event Name: NA: (0, 0, 1992)
# Row:420, Read... Event Type: Storm, Event Name: NA: (4, 0, 1997)
# Row:421, Read... Event Type: Winter, Event Name: NA: (0, 0, 1997)
# Row:422, Read... Event Type: Storm, Event Name: NA: (2, 0, 2001)
# Row:423, Read... Event Type: Winter, Event Name: NA: (45, 0, 2005)
# Row:424, Read... Event Type: Typhoon, Event Name: NA: (50000, 0, 1912)
# Row:425, Read... Event Type: Typhoon, Event Name: NA: (100000, 0, 1922)
# Row:426, Read... Event Type: Typhoon, Event Name: NA: (5000, 0, 1927)
# Row:427, Read... Event Type: Typhoon, Event Name: NA: (800, 0, 1948)
# Row:428, Read... Event Type: Typhoon, Event Name: NA: (2000, 0, 1956)
# Row:429, Read... Event Type: Typhoon, Event Name: Ellen: (1064, 0, 1959)
# Row:430, Read... Event Type: Typhoon, Event Name: Iris: (720, 0, 1959)
# Row:431, Read... Event Type: Typhoon, Event Name: Ruby: (686, 0, 1964)
# Row:432, Read... Event Type: Typhoon, Event Name: Fran: (107, 0, 1970)
# Row:433, Read... Event Type: Typhoon, Event Name: Joe: (188, 0, 1980)
# Row:434, Read... Event Type: Storm, Event Name: NA: (0, 0, 1981)
# Row:435, Read... Event Type: Storm, Event Name: NA: (275, 0, 1983)
# Row:436, Read... Event Type: Tornado, Event Name: NA: (54, 0, 1983)
# Row:437, Read... Event Type: Typhoon, Event Name: NA: (30, 0, 1983)
# Row:438, Read... Event Type: Typhoon, Event Name: Ellen: (82, 0, 1983)
# Row:439, Read... Event Type: Storm, Event Name: NA: (69, 0, 1983)
# Row:440, Read... Event Type: Typhoon, Event Name: Ike: (13, 0, 1984)
# Row:441, Read... Event Type: Typhoon, Event Name: Freda: (0, 0, 1984)
# Row:442, Read... Event Type: Typhoon, Event Name: NA: (0, 0, 1984)
# Row:443, Read... Event Type: Storm, Event Name: NA: (108, 0, 1985)
# Row:444, Read... Event Type: Storm, Event Name: NA: (11, 0, 1985)
# Row:445, Read... Event Type: Typhoon, Event Name: NA: (177, 0, 1985)
# Row:446, Read... Event Type: Storm, Event Name: NA: (9, 50000, 1986)
# Row:447, Read... Event Type: Storm, Event Name: NA: (36, 3200, 1986)
# Row:448, Read... Event Type: Typhoon, Event Name: Peggy: (172, 380000, 1986)
# Row:449, Read... Event Type: Typhoon, Event Name: NA: (43, 54000, 1986)
# Row:450, Read... Event Type: Winter, Event Name: NA: (0, 0, 1986)
# Row:451, Read... Event Type: Storm, Event Name: NA: (100, 0, 1986)
# Row:452, Read... Event Type: Typhoon, Event Name: Vera: (8, 940000, 1986)
# Row:453, Read... Event Type: Tornado, Event Name: NA: (2, 0, 1987)
# Row:454, Read... Event Type: Typhoon, Event Name: NA: (132, 0, 1987)
# Row:455, Read... Event Type: Tornado, Event Name: NA: (29, 0, 1987)
# Row:456, Read... Event Type: Storm, Event Name: NA: (101, 0, 1987)
# Row:457, Read... Event Type: Typhoon, Event Name: Gerald: (102, 120000, 1987)
# Row:458, Read... Event Type: Typhoon, Event Name: Ruth: (40, 0, 1987)
# Row:459, Read... Event Type: Storm, Event Name: NA: (65, 0, 1988)
# Row:460, Read... Event Type: Storm, Event Name: NA: (70, 0, 1988)
# Row:461, Read... Event Type: Typhoon, Event Name: Bill (n°7): (194, 0, 1988)
# Row:462, Read... Event Type: Typhoon, Event Name: Kit: (6, 0, 1988)
# Row:463, Read... Event Type: Storm, Event Name: NA: (157, 400000, 1989)
# Row:464, Read... Event Type: Typhoon, Event Name: Vera: (550, 485000, 1989)
# Row:465, Read... Event Type: Typhoon, Event Name: Brian: (31, 0, 1989)
# Row:466, Read... Event Type: Typhoon, Event Name: Brenda: (84, 0, 1989)
# Row:467, Read... Event Type: Winter, Event Name: NA: (67, 0, 1989)
# Row:468, Read... Event Type: Typhoon, Event Name: Hope: (200, 0, 1989)
# Row:469, Read... Event Type: Storm, Event Name: NA: (26, 0, 1989)
# Row:470, Read... Event Type: Typhoon, Event Name: N°5: (56, 16000, 1990)
# Row:471, Read... Event Type: Typhoon, Event Name: N°6: (16, 28000, 1990)
# Row:472, Read... Event Type: Typhoon, Event Name: Yancy: (144, 157000, 1990)
# Row:473, Read... Event Type: Tornado, Event Name: NA: (25, 335, 1990)
# Row:474, Read... Event Type: Winter, Event Name: NA: (36, 0, 1990)
# Row:475, Read... Event Type: Typhoon, Event Name: Tasha: (108, 83000, 1990)
# Row:476, Read... Event Type: Typhoon, Event Name: Abe: (115, 688000, 1990)
# Row:477, Read... Event Type: Typhoon, Event Name: Dot: (26, 0, 1990)
# Row:478, Read... Event Type: Typhoon, Event Name: Dot: (120, 154000, 1990)
# Row:479, Read... Event Type: Typhoon, Event Name: NA: (68, 743000, 1990)
# Row:480, Read... Event Type: Tornado, Event Name: NA: (2, 0, 1990)
# Row:481, Read... Event Type: Storm, Event Name: NA: (69, 28000, 1991)
# Row:482, Read... Event Type: Typhoon, Event Name: Amy: (100, 465330, 1991)
# Row:483, Read... Event Type: Typhoon, Event Name: Fred: (14, 175050, 1991)
# Row:484, Read... Event Type: Typhoon, Event Name: Zeke: (33, 117560, 1991)
# Row:485, Read... Event Type: Storm, Event Name: NA: (35, 68700, 1992)
# Row:486, Read... Event Type: Storm, Event Name: NA: (109, 96000, 1992)
# Row:487, Read... Event Type: Storm, Event Name: NA: (448, 68700, 1992)
# Row:488, Read... Event Type: Winter, Event Name: NA: (0, 0, 1992)
# Row:489, Read... Event Type: Storm, Event Name: NA: (47, 110000, 1992)
# Row:490, Read... Event Type: Tropical storm, Event Name: Polly: (165, 412400, 1992)
# Row:491, Read... Event Type: Typhoon, Event Name: Ted: (53, 425000, 1992)
# Row:492, Read... Event Type: Storm, Event Name: NA: (0, 90000, 1992)
# Row:493, Read... Event Type: Storm, Event Name: NA: (31, 88000, 1993)
# Row:494, Read... Event Type: Typhoon, Event Name: Tasha: (28, 433920, 1993)
# Row:495, Read... Event Type: Winter, Event Name: NA: (15, 0, 1993)
# Row:496, Read... Event Type: Cyclone, Event Name: NA: (19, 0, 1993)
# Row:497, Read... Event Type: Storm, Event Name: NA: (93, 41000, 1993)
# Row:498, Read... Event Type: Typhoon, Event Name: Koryn: (10, 219670, 1993)
# Row:499, Read... Event Type: Storm, Event Name: Levis: (0, 7380, 1993)
# Row:500, Read... Event Type: Typhoon, Event Name: Abe: (10, 12610, 1993)
# Row:501, Read... Event Type: Typhoon, Event Name: Becky: (7, 263670, 1993)
# Row:502, Read... Event Type: Typhoon, Event Name: Dot: (1, 286370, 1993)
# Row:503, Read... Event Type: Typhoon, Event Name: Ira: (0, 15890, 1993)
# Row:504, Read... Event Type: Storm, Event Name: NA: (101, 200000, 1994)
# Row:505, Read... Event Type: Typhoon, Event Name: 9403: (90, 700000, 1994)
# Row:506, Read... Event Type: Typhoon, Event Name: Russ: (74, 252770, 1994)
# Row:507, Read... Event Type: Typhoon, Event Name: Tim: (47, 96300, 1994)
# Row:508, Read... Event Type: Typhoon, Event Name: Fred (9416): (1174, 1150000, 1994)
# Row:509, Read... Event Type: Storm, Event Name: NA: (4, 0, 1995)
# Row:510, Read... Event Type: Winter, Event Name: NA: (0, 240, 1995)
# Row:511, Read... Event Type: Tornado, Event Name: NA: (54, 35600, 1995)
# Row:512, Read... Event Type: Storm, Event Name: Helen: (26, 160000, 1995)
# Row:513, Read... Event Type: Typhoon, Event Name: Kent: (445, 87000, 1995)
# Row:514, Read... Event Type: Storm, Event Name: NA: (152, 120000, 1995)
# Row:515, Read... Event Type: Winter, Event Name: NA: (48, 68000, 1996)
# Row:516, Read... Event Type: Storm, Event Name: NA: (6, 0, 1996)
# Row:517, Read... Event Type: Typhoon, Event Name: Herb: (85, 837000, 1996)
# Row:518, Read... Event Type: Typhoon, Event Name: Sally: (197, 1500000, 1996)
# Row:519, Read... Event Type: Typhoon, Event Name: Willie: (147, 156700, 1996)
# Row:520, Read... Event Type: Winter, Event Name: NA: (36, 0, 1996)
# Row:521, Read... Event Type: Winter, Event Name: NA: (34, 29000, 1997)
# Row:522, Read... Event Type: Tornado, Event Name: NA: (40, 0, 1997)
# Row:523, Read... Event Type: Storm, Event Name: NA: (28, 156000, 1997)
# Row:524, Read... Event Type: Typhoon, Event Name: Victor: (1, 0, 1997)
# Row:525, Read... Event Type: Typhoon, Event Name: Winnie: (140, 2675000, 1997)
# Row:526, Read... Event Type: Typhoon, Event Name: Zita: (7, 326500, 1997)
# Row:527, Read... Event Type: Winter, Event Name: NA: (0, 0, 1998)
# Row:528, Read... Event Type: Storm, Event Name: NA: (12, 0, 1998)
# Row:529, Read... Event Type: Storm, Event Name: NA: (62, 0, 1998)
# Row:530, Read... Event Type: Storm, Event Name: NA: (17, 37200, 1998)
# Row:531, Read... Event Type: Storm, Event Name: NA: (22, 0, 1999)
# Row:532, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1999)
# Row:533, Read... Event Type: Tornado, Event Name: NA: (13, 0, 1999)
# Row:534, Read... Event Type: Tropical storm, Event Name: Wendy: (192, 277900, 1999)
# Row:535, Read... Event Type: Storm, Event Name: NA: (200, 180000, 1999)
# Row:536, Read... Event Type: Typhoon, Event Name: York: (15, 24000, 1999)
# Row:537, Read... Event Type: Typhoon, Event Name: Dan: (30, 241600, 1999)
# Row:538, Read... Event Type: Typhoon, Event Name: Sam: (5, 18000, 1999)
# Row:539, Read... Event Type: Winter, Event Name: NA: (11, 39900, 1999)
# Row:540, Read... Event Type: Storm, Event Name: NA: (16, 0, 2000)
# Row:541, Read... Event Type: Winter, Event Name: NA: (9, 3100, 2000)
# Row:542, Read... Event Type: Storm, Event Name: NA: (15, 5000, 2000)
# Row:543, Read... Event Type: Storm, Event Name: NA: (33, 0, 2000)
# Row:544, Read... Event Type: Tornado, Event Name: NA: (11, 480, 2000)
# Row:545, Read... Event Type: Storm, Event Name: NA: (10, 13288, 2000)
# Row:546, Read... Event Type: Typhoon, Event Name: Bilis: (11, 69443, 2000)
# Row:547, Read... Event Type: Typhoon, Event Name: Prapiroon: (4, 0, 2000)
# Row:548, Read... Event Type: Typhoon, Event Name: Maria: (47, 169000, 2000)
# Row:549, Read... Event Type: Typhoon, Event Name: Wukong: (6, 0, 2000)
# Row:550, Read... Event Type: Winter, Event Name: NA: (49, 12000, 2001)
# Row:551, Read... Event Type: Typhoon, Event Name: Chebi: (125, 473000, 2001)
# Row:552, Read... Event Type: Typhoon, Event Name: Durian and Utor: (0, 0, 2001)
# Row:553, Read... Event Type: Typhoon, Event Name: Yutu: (0, 85000, 2001)
# Row:554, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 2001)
# Row:555, Read... Event Type: Storm, Event Name: NA: (15, 0, 2001)
# Row:556, Read... Event Type: Storm, Event Name: NA: (12, 0, 2001)
# Row:557, Read... Event Type: Storm, Event Name: NA: (0, 0, 2002)
# Row:558, Read... Event Type: Typhoon, Event Name: Rammasun: (5, 80000, 2002)
# Row:559, Read... Event Type: Storm, Event Name: NA: (25, 0, 2002)
# Row:560, Read... Event Type: Typhoon, Event Name: Sinlaku: (17, 144000, 2002)
# Row:561, Read... Event Type: Tropical storm, Event Name: Hagupit: (25, 0, 2002)
# Row:562, Read... Event Type: Tornado, Event Name: NA: (26, 32500, 2002)
# Row:563, Read... Event Type: Storm, Event Name: NA: (1, 0, 2003)
# Row:564, Read... Event Type: Typhoon, Event Name: Imbudo: (20, 0, 2003)
# Row:565, Read... Event Type: Tornado, Event Name: NA: (2, 0, 2003)
# Row:566, Read... Event Type: Typhoon, Event Name: Dujuan: (38, 241000, 2003)
# Row:567, Read... Event Type: Typhoon, Event Name: Nepartak: (0, 196938, 2003)
# Row:568, Read... Event Type: Tornado, Event Name: NA: (7, 6000, 2004)
# Row:569, Read... Event Type: Storm, Event Name: NA: (0, 280, 2004)
# Row:570, Read... Event Type: Storm, Event Name: NA: (0, 12700, 2004)
# Row:571, Read... Event Type: Storm, Event Name: NA: (46, 0, 2004)
# Row:572, Read... Event Type: Typhoon, Event Name: Rananim: (188, 2190000, 2004)
# Row:573, Read... Event Type: Typhoon, Event Name: Aere: (0, 0, 2004)
# Row:574, Read... Event Type: Tornado, Event Name: NA: (6, 4000, 2004)
# Row:575, Read... Event Type: Winter, Event Name: NA: (36, 300000, 2005)
# Row:576, Read... Event Type: Winter, Event Name: NA: (1, 0, 2005)
# Row:577, Read... Event Type: Storm, Event Name: NA: (19, 16915, 2005)
# Row:578, Read... Event Type: Winter, Event Name: NA: (15, 0, 2005)
# Row:579, Read... Event Type: Tornado, Event Name: NA: (9, 0, 2005)
# Row:580, Read... Event Type: Storm, Event Name: NA: (0, 6000, 2005)
# Row:581, Read... Event Type: Typhoon, Event Name: Haitang: (9, 260000, 2005)
# Row:582, Read... Event Type: Storm, Event Name: NA: (8, 0, 2005)
# Row:583, Read... Event Type: Tornado, Event Name: NA: (15, 0, 2005)
# Row:584, Read... Event Type: Typhoon, Event Name: Matsa: (19, 850000, 2005)
# Row:585, Read... Event Type: Typhoon, Event Name: Talim: (159, 1900000, 2005)
# Row:586, Read... Event Type: Typhoon, Event Name: Khanun: (16, 0, 2005)
# Row:587, Read... Event Type: Tropical storm, Event Name: Damrey: (25, 0, 2005)
# Row:588, Read... Event Type: Typhoon, Event Name: Longwang: (95, 148000, 2005)
# Row:589, Read... Event Type: Storm, Event Name: NA: (0, 50, 1968)
# Row:590, Read... Event Type: Tornado, Event Name: NA: (1, 0, 1983)
# Row:591, Read... Event Type: Storm, Event Name: NA: (4, 2500, 1986)
# Row:592, Read... Event Type: Hurricane, Event Name: Joan: (26, 50000, 1988)
# Row:593, Read... Event Type: Tornado, Event Name: NA: (5, 0, 2001)
# Row:594, Read... Event Type: Hurricane, Event Name: Beta: (0, 0, 2005)
# Row:595, Read... Event Type: Tornado, Event Name: NA: (500, 0, 1951)
# Row:596, Read... Event Type: Cyclone, Event Name: Elinah: (33, 23000, 1983)
# Row:597, Read... Event Type: Cyclone, Event Name: NA: (2, 5568, 1985)
# Row:598, Read... Event Type: Cyclone, Event Name: Jan: (24, 9000, 1987)
# Row:599, Read... Event Type: Cyclone, Event Name: Kalafandji; Firinga: (0, 5236, 1989)
# Row:600, Read... Event Type: Storm, Event Name: NA: (0, 0, 2003)
# Row:601, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1942)
# Row:602, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1943)
# Row:603, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1946)
# Row:604, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1967)
# Row:605, Read... Event Type: Cyclone, Event Name: Daman: (0, 0, 1981)
# Row:606, Read... Event Type: Cyclone, Event Name: Sally: (5, 25000, 1987)
# Row:607, Read... Event Type: Cyclone, Event Name: Peni: (1, 0, 1990)
# Row:608, Read... Event Type: Cyclone, Event Name: Martin: (19, 0, 1997)
# Row:609, Read... Event Type: Cyclone, Event Name: Trina: (0, 0, 2001)
# Row:610, Read... Event Type: Cyclone, Event Name: Percy: (0, 0, 2005)
# Row:611, Read... Event Type: Hurricane, Event Name: Joan: (28, 60000, 1988)
# Row:612, Read... Event Type: Hurricane, Event Name: Cesar: (51, 0, 1996)
# Row:613, Read... Event Type: Storm, Event Name: NA: (3, 0, 1996)
# Row:614, Read... Event Type: Hurricane, Event Name: Mitch: (8, 91090, 1998)
# Row:615, Read... Event Type: Hurricane, Event Name: Stan: (0, 0, 2005)
# Row:616, Read... Event Type: Winter, Event Name: NA: (2, 0, 2005)
# Row:617, Read... Event Type: Hurricane, Event Name: NA: (600, 0, 1926)
# Row:618, Read... Event Type: Hurricane, Event Name: NA: (2500, 0, 1932)
# Row:619, Read... Event Type: Hurricane, Event Name: NA: (35, 0, 1935)
# Row:620, Read... Event Type: Storm, Event Name: NA: (0, 0, 1944)
# Row:621, Read... Event Type: Hurricane, Event Name: NA: (3, 12000, 1948)
# Row:622, Read... Event Type: Hurricane, Event Name: NA: (11, 6000, 1948)
# Row:623, Read... Event Type: Hurricane, Event Name: Flora: (1750, 500000, 1963)
# Row:624, Read... Event Type: Hurricane, Event Name: NA: (0, 0, 1964)
# Row:625, Read... Event Type: Hurricane, Event Name: Inez: (5, 18000, 1966)
# Row:626, Read... Event Type: Hurricane, Event Name: Gladys: (0, 0, 1968)
# Row:627, Read... Event Type: Hurricane, Event Name: NA: (20, 0, 1970)
# Row:628, Read... Event Type: Storm, Event Name: NA: (6, 0, 1978)
# Row:629, Read... Event Type: Hurricane, Event Name: Allen: (0, 0, 1980)
# Row:630, Read... Event Type: Hurricane, Event Name: Alberto: (24, 85000, 1982)
# Row:631, Read... Event Type: Hurricane, Event Name: Kate: (4, 0, 1985)
# Row:632, Read... Event Type: Storm, Event Name: NA: (0, 0, 1988)
# Row:633, Read... Event Type: Hurricane, Event Name: Gilbert: (0, 0, 1988)
# Row:634, Read... Event Type: Storm, Event Name: NA: (5, 1000000, 1993)
# Row:635, Read... Event Type: Hurricane, Event Name: Gordon: (2, 101968, 1994)
# Row:636, Read... Event Type: Hurricane, Event Name: Allison: (2, 0, 1995)
# Row:637, Read... Event Type: Hurricane, Event Name: Lilli: (0, 13000, 1996)
# Row:638, Read... Event Type: Hurricane, Event Name: Georges: (6, 0, 1998)
# Row:639, Read... Event Type: Hurricane, Event Name: Irene: (4, 0, 1999)
# Row:640, Read... Event Type: Hurricane, Event Name: Michelle: (5, 87000, 2001)
# Row:641, Read... Event Type: Tropical storm, Event Name: Isidore: (0, 0, 2002)
# Row:642, Read... Event Type: Hurricane, Event Name: Lili: (3, 0, 2002)
# Row:643, Read... Event Type: Hurricane, Event Name: Charley: (4, 1000000, 2004)
# Row:644, Read... Event Type: Hurricane, Event Name: Ivan: (0, 0, 2004)
# Row:645, Read... Event Type: Hurricane, Event Name: Dennis: (16, 1400000, 2005)
# Row:646, Read... Event Type: Hurricane, Event Name: Wilma: (4, 0, 2005)
# Row:647, Read... Event Type: Storm, Event Name: NA: (3, 100, 1969)
# Row:648, Read... Event Type: Storm, Event Name: NA: (0, 0, 1983)
# Row:649, Read... Event Type: Tornado, Event Name: NA: (0, 10000, 2003)
# Row:650, Read... Event Type: Winter, Event Name: NA: (0, 0, 2004)
# Row:651, Read... Event Type: Winter, Event Name: NA: (0, 0, 2002)
# Row:652, Read... Event Type: Winter, Event Name: NA: (0, 0, 2005)
# Row:653, Read... Event Type: Winter, Event Name: NA: (0, 0, 1981)
# Row:654, Read... Event Type: Storm, Event Name: NA: (0, 0, 1984)
# Row:655, Read... Event Type: Storm, Event Name: NA: (0, 15000, 1987)
# Row:656, Read... Event Type: Winter, Event Name: Capella: (0, 0, 1976)
# Row:657, Read... Event Type: Storm, Event Name: NA: (0, 0, 1980)
# Row:658, Read... Event Type: Winter, Event Name: NA: (9, 250000, 1981)
# Row:659, Read... Event Type: Storm, Event Name: NA: (2, 0, 1983)
# Row:660, Read... Event Type: Storm, Event Name: NA: (0, 0, 1985)
# Row:661, Read... Event Type: Winter, Event Name: Daria: (0, 190960, 1990)
# Row:662, Read... Event Type: Storm, Event Name: Anatol: (7, 276000, 1999)
# Row:663, Read... Event Type: Storm, Event Name: NA: (1, 0, 2002)
# Row:664, Read... Event Type: Storm, Event Name: NA: (4, 0, 2005)
# Row:665, Read... Event Type: Storm, Event Name: NA: (0, 0, 1995)
# Row:666, Read... Event Type: Hurricane, Event Name: NA: (2000, 0, 1930)
# Row:667, Read... Event Type: Hurricane, Event Name: Edith: (0, 2600, 1963)
# Row:668, Read... Event Type: Hurricane, Event Name: NA: (0, 0, 1970)
# Row:669, Read... Event Type: Hurricane, Event Name: David & Federick: (40, 44650, 1979)
# Row:670, Read... Event Type: Hurricane, Event Name: Allen: (0, 0, 1980)
# Row:671, Read... Event Type: Hurricane, Event Name: Klaus: (2, 2000, 1984)
# Row:672, Read... Event Type: Hurricane, Event Name: Hugo: (0, 20000, 1989)
# Row:673, Read... Event Type: Hurricane, Event Name: Luis: (1, 3428, 1995)
# Row:674, Read... Event Type: Hurricane, Event Name: Lenny: (0, 0, 1999)
# Row:675, Read... Event Type: Hurricane, Event Name: Iris: (3, 0, 2001)
# Row:676, Read... Event Type: Hurricane, Event Name: San Zenon: (2000, 40000, 1930)
# Row:677, Read... Event Type: Hurricane, Event Name: Flora: (400, 60000, 1963)
# Row:678, Read... Event Type: Hurricane, Event Name: Cleo: (7, 1000, 1964)
# Row:679, Read... Event Type: Hurricane, Event Name: Inez: (74, 5000, 1966)
# Row:680, Read... Event Type: Hurricane, Event Name: David & Frederick: (1400, 150000, 1979)
# Row:681, Read... Event Type: Hurricane, Event Name: Allen: (7, 47000, 1980)
# Row:682, Read... Event Type: Storm, Event Name: NA: (12, 0, 1986)
# Row:683, Read... Event Type: Hurricane, Event Name: Emily: (3, 23700, 1987)
# Row:684, Read... Event Type: Hurricane, Event Name: Hugo: (0, 0, 1989)
# Row:685, Read... Event Type: Storm, Event Name: NA: (9, 0, 1995)
# Row:686, Read... Event Type: Tornado, Event Name: NA: (2, 0, 1995)
# Row:687, Read... Event Type: Hurricane, Event Name: Hortense: (23, 0, 1996)
# Row:688, Read... Event Type: Hurricane, Event Name: Georges: (347, 1981500, 1998)
# ...
# Row:2488, Read... Event Type: Tornado, Event Name: NA: (1, 0, 1998)
# Row:2489, Read... Event Type: Tornado, Event Name: NA: (43, 100000, 1998)
# Row:2490, Read... Event Type: Tornado, Event Name: NA: (0, 3000000, 1998)
# Row:2491, Read... Event Type: Storm, Event Name: NA: (16, 27000, 1998)
# Row:2492, Read... Event Type: Storm, Event Name: NA: (0, 0, 1998)
# Row:2493, Read... Event Type: Tropical storm, Event Name: Charley: (17, 25000, 1998)
# Row:2494, Read... Event Type: Tornado, Event Name: NA: (9, 0, 1998)
# Row:2495, Read... Event Type: Tornado, Event Name: NA: (13, 200500, 1998)
# Row:2496, Read... Event Type: Hurricane, Event Name: Bonnie: (0, 256000, 1998)
# Row:2497, Read... Event Type: Storm, Event Name: NA: (0, 2000, 1998)
# Row:2498, Read... Event Type: Winter, Event Name: NA: (10, 370000, 1998)
# Row:2499, Read... Event Type: Winter, Event Name: NA: (48, 1000000, 1999)
# Row:2500, Read... Event Type: Tornado, Event Name: NA: (8, 90000, 1999)
# Row:2501, Read... Event Type: Storm, Event Name: NA: (3, 0, 1999)
# Row:2502, Read... Event Type: Tornado, Event Name: NA: (9, 0, 1999)
# Row:2503, Read... Event Type: Tornado, Event Name: NA: (9, 41000, 1999)
# Row:2504, Read... Event Type: Storm, Event Name: NA: (2, 34000, 1999)
# Row:2505, Read... Event Type: Tornado, Event Name: NA: (0, 0, 1999)
# Row:2506, Read... Event Type: Tornado, Event Name: NA: (49, 1000000, 1999)
# Row:2507, Read... Event Type: Storm, Event Name: NA: (2, 1500, 1999)
# Row:2508, Read... Event Type: Tornado, Event Name: NA: (1, 150000, 1999)
# Row:2509, Read... Event Type: Hurricane, Event Name: Bret: (0, 34000, 1999)
# Row:2510, Read... Event Type: Hurricane, Event Name: Floyd: (77, 7000000, 1999)
# Row:2511, Read... Event Type: Hurricane, Event Name: Irene: (6, 100000, 1999)
# Row:2512, Read... Event Type: Storm, Event Name: NA: (10, 1300000, 1999)
# Row:2513, Read... Event Type: Tornado, Event Name: NA: (4, 7000, 1999)
# Row:2514, Read... Event Type: Hurricane, Event Name: Dennis: (0, 43000, 1999)
# Row:2515, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2000)
# Row:2516, Read... Event Type: Tornado, Event Name: NA: (22, 0, 2000)
# Row:2517, Read... Event Type: Tornado, Event Name: NA: (5, 650000, 2000)
# Row:2518, Read... Event Type: Tornado, Event Name: NA: (5, 450000, 2000)
# Row:2519, Read... Event Type: Storm, Event Name: NA: (0, 28500, 2000)
# Row:2520, Read... Event Type: Storm, Event Name: NA: (0, 0, 2000)
# Row:2521, Read... Event Type: Tornado, Event Name: NA: (1, 8100, 2000)
# Row:2522, Read... Event Type: Tornado, Event Name: NA: (1, 0, 2000)
# Row:2523, Read... Event Type: Storm, Event Name: Leslie: (2, 219000, 2000)
# Row:2524, Read... Event Type: Winter, Event Name: NA: (0, 0, 2000)
# Row:2525, Read... Event Type: Tornado, Event Name: NA: (12, 0, 2000)
# Row:2526, Read... Event Type: Winter, Event Name: NA: (57, 10000, 2000)
# Row:2527, Read... Event Type: Winter, Event Name: NA: (4, 350000, 2005)
# Row:2528, Read... Event Type: Tornado, Event Name: NA: (7, 0, 2001)
# Row:2529, Read... Event Type: Winter, Event Name: NA: (11, 0, 2001)
# Row:2530, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2001)
# Row:2531, Read... Event Type: Tornado, Event Name: NA: (0, 1800, 2001)
# Row:2532, Read... Event Type: Hurricane, Event Name: Allison: (33, 6000000, 2001)
# Row:2533, Read... Event Type: Storm, Event Name: NA: (2, 0, 2001)
# Row:2534, Read... Event Type: Tornado, Event Name: NA: (4, 0, 2001)
# Row:2535, Read... Event Type: Tornado, Event Name: NA: (1, 0, 2001)
# Row:2536, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2001)
# Row:2537, Read... Event Type: Tornado, Event Name: NA: (3, 10000, 2001)
# Row:2538, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2001)
# Row:2539, Read... Event Type: Storm, Event Name: NA: (0, 0, 2001)
# Row:2540, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2001)
# Row:2541, Read... Event Type: Tornado, Event Name: NA: (2, 30000, 2001)
# Row:2542, Read... Event Type: Tornado, Event Name: NA: (0, 4000, 2001)
# Row:2543, Read... Event Type: Tornado, Event Name: NA: (0, 7000, 2001)
# Row:2544, Read... Event Type: Storm, Event Name: NA: (11, 0, 2001)
# Row:2545, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2001)
# Row:2546, Read... Event Type: Winter, Event Name: NA: (24, 0, 2002)
# Row:2547, Read... Event Type: Winter, Event Name: NA: (28, 400000, 2002)
# Row:2548, Read... Event Type: Winter, Event Name: NA: (20, 0, 2002)
# Row:2549, Read... Event Type: Storm, Event Name: NA: (6, 51000, 2002)
# Row:2550, Read... Event Type: Tornado, Event Name: NA: (2, 0, 2002)
# Row:2551, Read... Event Type: Tornado, Event Name: NA: (1, 0, 2002)
# Row:2552, Read... Event Type: Tornado, Event Name: NA: (10, 0, 2002)
# Row:2553, Read... Event Type: Tornado, Event Name: NA: (0, 20000, 2002)
# Row:2554, Read... Event Type: Hurricane, Event Name: Isidore: (3, 70000, 2002)
# Row:2555, Read... Event Type: Tornado, Event Name: NA: (35, 0, 2002)
# Row:2556, Read... Event Type: Hurricane, Event Name: Lili: (0, 260000, 2002)
# Row:2557, Read... Event Type: Winter, Event Name: NA: (22, 113000, 2002)
# Row:2558, Read... Event Type: Storm, Event Name: NA: (13, 0, 2002)
# Row:2559, Read... Event Type: Winter, Event Name: NA: (18, 0, 2002)
# Row:2560, Read... Event Type: Typhoon, Event Name: Pongsona: (0, 0, 2002)
# Row:2561, Read... Event Type: Winter, Event Name: NA: (44, 6000, 2003)
# Row:2562, Read... Event Type: Tornado, Event Name: NA: (6, 5000000, 2003)
# Row:2563, Read... Event Type: Winter, Event Name: NA: (0, 33600, 2003)
# Row:2564, Read... Event Type: Tornado, Event Name: NA: (45, 20000, 2003)
# Row:2565, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2003)
# Row:2566, Read... Event Type: Hurricane, Event Name: Isabel: (21, 5000000, 2003)
# Row:2567, Read... Event Type: Storm, Event Name: NA: (8, 0, 2003)
# Row:2568, Read... Event Type: Winter, Event Name: NA: (13, 0, 2003)
# Row:2569, Read... Event Type: Storm, Event Name: NA: (4, 400000, 2003)
# Row:2570, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2003)
# Row:2571, Read... Event Type: Tropical storm, Event Name: Bill: (0, 16000, 2003)
# Row:2572, Read... Event Type: Winter, Event Name: NA: (56, 0, 2004)
# Row:2573, Read... Event Type: Winter, Event Name: NA: (0, 0, 2004)
# Row:2574, Read... Event Type: Storm, Event Name: NA: (5, 300000, 2004)
# Row:2575, Read... Event Type: Tornado, Event Name: NA: (4, 500000, 2004)
# Row:2576, Read... Event Type: Storm, Event Name: NA: (10, 700000, 2004)
# Row:2577, Read... Event Type: Storm, Event Name: NA: (5, 15000, 2004)
# Row:2578, Read... Event Type: Tornado, Event Name: NA: (0, 6900, 2004)
# Row:2579, Read... Event Type: Storm, Event Name: NA: (4, 0, 2004)
# Row:2580, Read... Event Type: Hurricane, Event Name: Charley: (16, 6800000, 2004)
# Row:2581, Read... Event Type: Hurricane, Event Name: Gaston: (7, 62000, 2004)
# Row:2582, Read... Event Type: Hurricane, Event Name: Frances: (2, 4400000, 2004)
# Row:2583, Read... Event Type: Hurricane, Event Name: Ivan: (52, 6000000, 2004)
# Row:2584, Read... Event Type: Hurricane, Event Name: Jeanne: (6, 7000000, 2004)
# Row:2585, Read... Event Type: Tornado, Event Name: NA: (0, 2100, 2004)
# Row:2586, Read... Event Type: Tornado, Event Name: NA: (9, 0, 2004)
# Row:2587, Read... Event Type: Winter, Event Name: NA: (20, 350000, 2005)
# Row:2588, Read... Event Type: Storm, Event Name: NA: (0, 350000, 2005)
# Row:2589, Read... Event Type: Hurricane, Event Name: Dennis: (5, 0, 2005)
# Row:2590, Read... Event Type: Hurricane, Event Name: Katrina: (1322, 125000000, 2005)
# Row:2591, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2005)
# Row:2592, Read... Event Type: Hurricane, Event Name: Rita: (0, 6000000, 2005)
# Row:2593, Read... Event Type: Hurricane, Event Name: Wilma: (4, 120000, 2005)
# Row:2594, Read... Event Type: Winter, Event Name: NA: (10, 0, 2005)
# Row:2595, Read... Event Type: Storm, Event Name: NA: (0, 0, 1993)
# Row:2596, Read... Event Type: Storm, Event Name: NA: (1, 0, 1997)
# Row:2597, Read... Event Type: Storm, Event Name: NA: (1, 0, 1999)
# Row:2598, Read... Event Type: Storm, Event Name: NA: (0, 0, 2000)
# Row:2599, Read... Event Type: Storm, Event Name: NA: (2, 25000, 2002)
# Row:2600, Read... Event Type: Storm, Event Name: NA: (7, 0, 2005)
# Row:2601, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1940)
# Row:2602, Read... Event Type: Cyclone, Event Name: NA: (100, 250, 1951)
# Row:2603, Read... Event Type: Cyclone, Event Name: Amanda: (0, 0, 1959)
# Row:2604, Read... Event Type: Cyclone, Event Name: Carlotta: (0, 0, 1972)
# Row:2605, Read... Event Type: Cyclone, Event Name: Wendy: (4, 0, 1972)
# Row:2606, Read... Event Type: Cyclone, Event Name: Gail: (0, 0, 1972)
# Row:2607, Read... Event Type: Storm, Event Name: Alison: (0, 0, 1975)
# Row:2608, Read... Event Type: Cyclone, Event Name: June: (0, 0, 1977)
# Row:2609, Read... Event Type: Cyclone, Event Name: Gordon: (0, 0, 1979)
# Row:2610, Read... Event Type: Cyclone, Event Name: Cliff: (0, 0, 1981)
# Row:2611, Read... Event Type: Cyclone, Event Name: Gyan: (0, 1000, 1981)
# Row:2612, Read... Event Type: Cyclone, Event Name: Eric & Nigel: (9, 173000, 1985)
# Row:2613, Read... Event Type: Cyclone, Event Name: Uma: (48, 25000, 1987)
# Row:2614, Read... Event Type: Cyclone, Event Name: Anne: (0, 0, 1988)
# Row:2615, Read... Event Type: Cyclone, Event Name: Bola: (0, 0, 1988)
# Row:2616, Read... Event Type: Cyclone, Event Name: Betsy: (2, 0, 1992)
# Row:2617, Read... Event Type: Cyclone, Event Name: Fran: (0, 0, 1992)
# Row:2618, Read... Event Type: Cyclone, Event Name: Prema: (4, 6000, 1993)
# Row:2619, Read... Event Type: Cyclone, Event Name: Yali; Zuman: (0, 0, 1998)
# Row:2620, Read... Event Type: Storm, Event Name: NA: (32, 0, 1999)
# Row:2621, Read... Event Type: Cyclone, Event Name: Paula: (1, 0, 2001)
# Row:2622, Read... Event Type: Cyclone, Event Name: Sose: (1, 0, 2001)
# Row:2623, Read... Event Type: Cyclone, Event Name: Ivy (P13): (2, 0, 2004)
# Row:2624, Read... Event Type: Hurricane, Event Name: Joan: (11, 0, 1988)
# Row:2625, Read... Event Type: Tropical storm, Event Name: Bret: (100, 4500, 1993)
# Row:2626, Read... Event Type: Hurricane, Event Name: Ivan: (5, 0, 2004)
# Row:2627, Read... Event Type: Typhoon, Event Name: NA: (1000, 0, 1953)
# Row:2628, Read... Event Type: Typhoon, Event Name: NA: (2300, 0, 1953)
# Row:2629, Read... Event Type: Typhoon, Event Name: NA: (56, 0, 1956)
# Row:2630, Read... Event Type: Typhoon, Event Name: Iris & Jean: (7000, 50000, 1964)
# Row:2631, Read... Event Type: Typhoon, Event Name: Wanda: (23, 0, 1971)
# Row:2632, Read... Event Type: Typhoon, Event Name: NA: (89, 0, 1971)
# Row:2633, Read... Event Type: Typhoon, Event Name: NA: (100, 0, 1973)
# Row:2634, Read... Event Type: Typhoon, Event Name: Sarah: (0, 0, 1977)
# Row:2635, Read... Event Type: Typhoon, Event Name: Joe (n°4): (132, 0, 1980)
# Row:2636, Read... Event Type: Typhoon, Event Name: Ruth (N°6): (176, 0, 1980)
# Row:2637, Read... Event Type: Typhoon, Event Name: Nancy (N°7): (70, 0, 1982)
# Row:2638, Read... Event Type: Storm, Event Name: NA: (76, 0, 1983)
# Row:2639, Read... Event Type: Typhoon, Event Name: Herbert (N°7); Kim (N°9); Lex (N°10): (578, 0, 1983)
# Row:2640, Read... Event Type: Typhoon, Event Name: Georgia (N°6): (80, 0, 1983)
# Row:2641, Read... Event Type: Typhoon, Event Name: NA: (21, 0, 1984)
# Row:2642, Read... Event Type: Typhoon, Event Name: Agnes (n°9): (134, 0, 1984)
# Row:2643, Read... Event Type: Typhoon, Event Name: Cecil: (798, 0, 1985)
# Row:2644, Read... Event Type: Typhoon, Event Name: Wayne (N°5): (435, 0, 1986)
# Row:2645, Read... Event Type: Typhoon, Event Name: Maury: (101, 0, 1987)
# Row:2646, Read... Event Type: Storm, Event Name: NA: (22, 0, 1987)
# Row:2647, Read... Event Type: Typhoon, Event Name: NA: (137, 0, 1988)
# Row:2648, Read... Event Type: Typhoon, Event Name: NA: (20, 0, 1988)
# Row:2649, Read... Event Type: Typhoon, Event Name: Irving: (104, 0, 1989)
# Row:2650, Read... Event Type: Typhoon, Event Name: Brian; Angela; Dan: (104, 0, 1989)
# Row:2651, Read... Event Type: Typhoon, Event Name: Cecil: (751, 21000, 1989)
# Row:2652, Read... Event Type: Typhoon, Event Name: Becky: (19, 0, 1990)
# Row:2653, Read... Event Type: Typhoon, Event Name: NA: (68, 0, 1990)
# Row:2654, Read... Event Type: Typhoon, Event Name: NA: (15, 0, 1990)
# Row:2655, Read... Event Type: Typhoon, Event Name: Fred: (17, 9500, 1991)
# Row:2656, Read... Event Type: Storm, Event Name: NA: (251, 1000, 1991)
# Row:2657, Read... Event Type: Storm, Event Name: NA: (8, 0, 1991)
# Row:2658, Read... Event Type: Typhoon, Event Name: Zeke: (21, 0, 1991)
# Row:2659, Read... Event Type: Typhoon, Event Name: Chuck: (14, 400, 1992)
# Row:2660, Read... Event Type: Typhoon, Event Name: Angela: (17, 18000, 1992)
# Row:2661, Read... Event Type: Typhoon, Event Name: Kyle: (130, 0, 1993)
# Row:2662, Read... Event Type: Storm, Event Name: NA: (3, 0, 1993)
# Row:2663, Read... Event Type: Typhoon, Event Name: Lola: (73, 0, 1993)
# Row:2664, Read... Event Type: Typhoon, Event Name: Luke: (30, 45000, 1994)
# Row:2665, Read... Event Type: Typhoon, Event Name: Zack: (16, 21200, 1995)
# Row:2666, Read... Event Type: Typhoon, Event Name: Frankie: (585, 362000, 1996)
# Row:2667, Read... Event Type: Typhoon, Event Name: Willie: (9, 138000, 1996)
# Row:2668, Read... Event Type: Storm, Event Name: NA: (33, 0, 1996)
# Row:2669, Read... Event Type: Typhoon, Event Name: Linda: (3682, 200000, 1997)
# Row:2670, Read... Event Type: Typhoon, Event Name: Fritz: (10, 5000, 1997)
# Row:2671, Read... Event Type: Tornado, Event Name: NA: (42, 0, 1998)
# Row:2672, Read... Event Type: Typhoon, Event Name: Chip; Elvis & Dawn: (283, 93200, 1998)
# Row:2673, Read... Event Type: Typhoon, Event Name: Faith & Gil: (43, 15000, 1998)
# Row:2674, Read... Event Type: Tornado, Event Name: NA: (10, 0, 1999)
# Row:2675, Read... Event Type: Storm, Event Name: NA: (3, 0, 2000)
# Row:2676, Read... Event Type: Storm, Event Name: NA: (0, 0, 2000)
# Row:2677, Read... Event Type: Typhoon, Event Name: Kaemi: (17, 7140, 2000)
# Row:2678, Read... Event Type: Storm, Event Name: NA: (0, 0, 2000)
# Row:2679, Read... Event Type: Storm, Event Name: NA: (0, 35, 2000)
# Row:2680, Read... Event Type: Tornado, Event Name: NA: (0, 0, 2000)
# Row:2681, Read... Event Type: Typhoon, Event Name: Wukong: (2, 3000, 2000)
# Row:2682, Read... Event Type: Typhoon, Event Name: Durian: (30, 0, 2001)
# Row:2683, Read... Event Type: Typhoon, Event Name: Usagi: (3, 3200, 2001)
# Row:2684, Read... Event Type: Typhoon, Event Name: Lingling (Nanang): (20, 0, 2001)
# Row:2685, Read... Event Type: Storm, Event Name: NA: (0, 100, 2002)
# Row:2686, Read... Event Type: Typhoon, Event Name: Koni: (0, 0, 2003)
# Row:2687, Read... Event Type: Typhoon, Event Name: Chanthu: (14, 7500, 2004)
# Row:2688, Read... Event Type: Typhoon, Event Name: Muifa: (56, 23000, 2004)
# Row:2689, Read... Event Type: Storm, Event Name: NA: (13, 0, 2005)
# 13
# Row:2690, Read... Event Type: Tropical storm, Event Name: Vicente: ('13', 'NA', 2005)
# Row:2691, Read... Event Type: Tropical storm, Event Name: Damrey: (75, 219250, 2005)
#
# Row:2692, Read... Event Type: Typhoon, Event Name: Kai Tak: ('NA', 'NA', 2005)
# Row:2693, Read... Event Type: Hurricane, Event Name: Hugo: (0, 21800, 1989)
# Row:2694, Read... Event Type: Hurricane, Event Name: Marilyn: (0, 10000, 1995)
# Row:2695, Read... Event Type: Hurricane, Event Name: Luis: (0, 2000, 1996)
# Row:2696, Read... Event Type: Hurricane, Event Name: Marilyn: (7, 136000, 1995)
# Row:2697, Read... Event Type: Hurricane, Event Name: Lenny: (3, 31500, 1999)
# Row:2698, Read... Event Type: Hurricane, Event Name: Jeanne: (0, 0, 2004)
# Row:2699, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1965)
# Row:2700, Read... Event Type: Cyclone, Event Name: NA: (0, 0, 1966)
# Row:2701, Read... Event Type: Cyclone, Event Name: Raja: (1, 0, 1986)
# Row:2702, Read... Event Type: Storm, Event Name: NA: (13, 0, 2001)
# Row:2703, Read... Event Type: Storm, Event Name: NA: (17, 0, 2001)
# Row:2704, Read... Event Type: Tropical storm, Event Name: NA: (17, 0, 2003)
# Row:2705, Read... Event Type: Storm, Event Name: NA: (11, 0, 2003)
# Row:2706, Read... Event Type: Winter, Event Name: NA: (8, 0, 2005)
# Row:2707, Read... Event Type: Storm, Event Name: NA: (11, 0, 1975)
# Row:2708, Read... Event Type: Cyclone, Event Name: Japhet: (8, 0, 2003)

# %% [markdown]
# Okay, once we can read the file, we need to:
# 1. consider only records that are in range, i.e.: ``start_year <= year <= end_year``
# 2. for each year in range:
#     * calculate the total for num_killed
#     * calculate the total for damage
#     * keep track of largest num_killed
#     * keep track of largest damage
#
# And, we need a data structure to keep track of all this.
#
# We already learned how to do this in OA2801...

# %%
def calc_disasters2(infile,start_year,end_year,isVerbose = True):
    '''function to calculate summary disaster statistics in range [start_year,end_year]
       for data in given filename.'''

    if isVerbose:
        print("Calculating statistics in file %s for range [%d,%d]." % 
              (infile, start_year, end_year))

    # we will use a dictionary to keep track of our statistics
    #   key is the year
    #   value is a list of [num_events,total_killed, total_damage, most_killed, most_damage]
    # let's initialize the dictionary
    stats_dict = {}
    for year in range(start_year,end_year+1):
        stats_dict[year] = [0,0,0,0,0] # Assigning the empty list 
        
        
    # open the file and get a "handle" on it
    file = open(infile, "r")

    # index to identify the first line or first apparence of a year
    i=0

    # looping throught the whole file once
    for line in file:

        # remove the special characters
        line = line.strip()  # string method that removes whitespace and special chars

        # skip any line with first character # 
        if line[0] == '#':
            continue

        # parse by comma
        values = line.split(',')
        # print(values)  # uncomment if you really want to check this...

        # give all tokens names to work with
        # type          - the type of disaster  -->typ
        # event_name    - the name of the disaster (if it exists)
        # num_killed    - the number of fatalities
        # damage        - total damage (in adjusted USD)
        # start_year    - year in which the disaster began  ---> year
        # start_month   - month in which the disaster began
        # start_day     - day of month on which the disaster began
        # iso           - three-letter country code
        # country_name  - full name
        # region        - global region
        # continent     - continent
        
        # for text data, strip() removes leading/trailing blanks
        # for numerical data, convert to int if a digit, otherwise use 0
        
        typ = values[0].strip()             
        event_name = values[1].strip()
        num_killed = 0 if not values[2].isdigit() else int(values[2]) #.isdigit determines 
        damage = 0 if not values[3].isdigit() else int(values[3])
        year = 0 if not values[4].isdigit() else int(values[4])
        start_month = 0 if not values[5].isdigit() else int(values[5])
        start_day = 0 if not values[6].isdigit() else int(values[6])
        iso = values[7].strip()
        country_name = values[8].strip()
        region = values[9].strip()
        continent = values[10].strip()
        
        if start_year <= year <= end_year:

            if isVerbose:
                print('Read...%s/%s: %d, %d, %d' % (typ,event_name,num_killed,damage,year))
            
            stats_dict[year][0] += 1
            stats_dict[year][1] += num_killed
            stats_dict[year][2] += damage
            stats_dict[year][3] = max(stats_dict[year][3],num_killed)
            stats_dict[year][4] = max(stats_dict[year][4],damage)
    # end of for-loop
    
    return stats_dict

# %%
calc_disasters2('wind_disasters.csv',1955,1960,False)
# Out:
# {1955: [19, 3895, 877000, 1500, 832000],
#  1956: [14, 3114, 0, 2000, 0],
#  1957: [9, 1139, 150000, 390, 150000],
#  1958: [13, 2620, 0, 1175, 0],
#  1959: [16, 9695, 672200, 5098, 600000],
#  1960: [20, 9164, 454041, 5149, 387000]}

# %% [markdown]
# ### Creating and using a customized Python class
#
# Okay, so

# %% [markdown]
# Consider the following class definition...

# %%
# The following class is complete and SHOULD NOT BE CHANGED
# without prior consent of the instructor.
class DisasterStat:
    '''Simple class to keep disaster statistics for a single year'''

    def __init__(self,year):
        self.year = year
        self.count = 0
        self.deaths = 0
        self.damage = 0
        self.max_deaths = 0
        self.max_damage = 0

    def add_disaster(self, deaths, damage):
        self.count += 1
        self.deaths += deaths
        self.damage += damage
        if deaths > self.max_deaths: # Deaths 
            self.max_deaths = deaths
        if damage > self.max_damage: # Damage
            self.max_damage = damage

    def __str__(self):
        return '%s,%d,%d,%d,%d,%d' % (self.year,self.count,self.deaths,self.damage,self.max_deaths,self.max_damage)

# end of class DisasterStat

# %% [markdown]
# ### For reflection
#
# #### 1. Do the final values for this DisasterStat make sense to you?
#
# #### 2. How would you use the DisasterStat class to answer the lab questions for a *single year*?
#
# #### 3. How would you use the DisasterState class to answer the lab questions for a *range of years*?
#
# Okay, let's try it...

# %%
def calc_disasters3(infile,start_year,end_year,isVerbose = True):
    '''function to calculate summary disaster statistics in range [start_year,end_year]
       for data in given filename.'''

    if isVerbose:
        print("Calculating statistics in file %s for range [%d,%d]." % 
              (infile, start_year, end_year))

    # we will use a dictionary to keep track of our statistics
    #   key is the year
    #   value is a list of [num_events,total_killed, total_damage, most_killed, most_damage]
    # let's initialize the dictionary
    stats_dict = {}
    for year in range(start_year,end_year+1):
        stats_dict[year] = DisasterStat(year) # Assigning the empty list 
        
        
    # open the file and get a "handle" on it
    file = open(infile, "r")

    # index to identify the first line or first apparence of a year
    i=0

    # looping throught the whole file once
    for line in file:

        # remove the special characters
        line = line.strip()  # string method that removes whitespace and special chars

        # skip any line with first character # 
        if line[0] == '#':
            continue

        # parse by comma
        values = line.split(',')
        # print(values)  # uncomment if you really want to check this...

        # give all tokens names to work with
        # type          - the type of disaster  -->typ
        # event_name    - the name of the disaster (if it exists)
        # num_killed    - the number of fatalities
        # damage        - total damage (in adjusted USD)
        # start_year    - year in which the disaster began  ---> year
        # start_month   - month in which the disaster began
        # start_day     - day of month on which the disaster began
        # iso           - three-letter country code
        # country_name  - full name
        # region        - global region
        # continent     - continent
        
        # for text data, strip() removes leading/trailing blanks
        # for numerical data, convert to int if a digit, otherwise use 0
        
        typ = values[0].strip()             
        event_name = values[1].strip()
        num_killed = 0 if not values[2].isdigit() else int(values[2]) #.isdigit determines 
        damage = 0 if not values[3].isdigit() else int(values[3])
        year = 0 if not values[4].isdigit() else int(values[4])
        start_month = 0 if not values[5].isdigit() else int(values[5])
        start_day = 0 if not values[6].isdigit() else int(values[6])
        iso = values[7].strip()
        country_name = values[8].strip()
        region = values[9].strip()
        continent = values[10].strip()
        
        if start_year <= year <= end_year:

            if isVerbose:
                print('Read...%s/%s: %d, %d, %d' % (typ,event_name,num_killed,damage,year))
            
#             stats_dict[year][0] += 1
#             stats_dict[year][1] += num_killed
#             stats_dict[year][2] += damage
#             stats_dict[year][3] = max(stats_dict[year][3],num_killed)
#             stats_dict[year][4] = max(stats_dict[year][4],damage)
            stats_dict[year].add_disaster(num_killed,damage)


        
    # end of for-loop
    
    return stats_dict

# %%
mydict = calc_disasters3('wind_disasters.csv',1955,1960,False)

# %%
for year in mydict:
    print(mydict[year])
# Out:
# 1955,19,3895,877000,1500,832000
# 1956,14,3114,0,2000,0
# 1957,9,1139,150000,390,150000
# 1958,13,2620,0,1175,0
# 1959,16,9695,672200,5098,600000
# 1960,20,9164,454041,5149,387000

# %% [markdown]
# ## Conclusion
#
# * One of the simplest uses of objects is as customized data containers.
# * Building such objects can make calculations easier.
# * What 'needs' to be included in the class depends on the computational task and the preferences of the designer.
# * Becoming proficient in this is an essential topic in software design, much of which is beyond the scope of this class.
# * But you should be familiar with the basics.
# * We will practice more...
